# %%
import requests

session = requests.Session()

url = "https://px.ads.linkedin.com/wa/"

payload = "{\"pids\":[2595146],\"scriptVersion\":142,\"time\":1713505720673,\"domain\":\"egov.maryland.gov\",\"url\":\"https://egov.maryland.gov/BusinessExpress/EntitySearch\",\"pageTitle\":\"Register Your Business Online | Maryland.gov\",\"websiteSignalRequestId\":\"5c979aef-9439-c442-4de4-023775ec6602\",\"isTranslated\":false,\"liFatId\":\"\",\"liGiant\":\"\",\"misc\":{\"psbState\":31},\"isLinkedInApp\":false,\"hem\":null,\"signalType\":\"CLICK\",\"href\":\"javascript:GoToBusiness('D01681188', 0, true);\",\"domAttributes\":{\"elementSemanticType\":null,\"elementValue\":null,\"elementType\":null,\"tagName\":\"A\",\"backgroundImageSrc\":null,\"imageSrc\":null,\"imageAlt\":null,\"innerText\":\"A & A CORPORATION\",\"elementTitle\":null,\"cursor\":\"pointer\",\"formAction\":\"/BusinessExpress/EntitySearch\",\"isFormSubmission\":false},\"innerElements\":null,\"elementCrumbsTree\":[{\"tagName\":\"div\",\"nthChild\":5,\"id\":\"siteWrapper\",\"classes\":[\"container\"]},{\"tagName\":\"section\",\"nthChild\":0,\"id\":\"bodyWrapper\",\"classes\":[\"clib_Container\"]},{\"tagName\":\"div\",\"nthChild\":1,\"classes\":[\"row-fluid\"]},{\"tagName\":\"div\",\"nthChild\":0,\"id\":\"contentWrapper\",\"classes\":[\"span12\"]},{\"tagName\":\"div\",\"nthChild\":3,\"classes\":[\"fp_form\"]},{\"tagName\":\"form\",\"nthChild\":0,\"classes\":[\"disabledirtycheck\"],\"attributes\":{\"action\":\"/BusinessExpress/EntitySearch\",\"method\":\"post\"}},{\"tagName\":\"fieldset\",\"nthChild\":9},{\"tagName\":\"div\",\"nthChild\":0,\"classes\":[\"busSearchAdjust\"]},{\"tagName\":\"div\",\"nthChild\":4,\"id\":\"businessFound\",\"classes\":[\"formItemDivider\",\"fp_formItem\"]},{\"tagName\":\"table\",\"nthChild\":1,\"id\":\"newTblBusSearch\",\"classes\":[\"responsiveTable\",\"table\",\"table-bordered\",\"table-striped\"]},{\"tagName\":\"tbody\",\"nthChild\":1},{\"tagName\":\"tr\",\"nthChild\":8},{\"tagName\":\"td\",\"nthChild\":1,\"attributes\":{\"data-title\":\"Business Name\"}},{\"tagName\":\"a\",\"nthChild\":0,\"attributes\":{\"href\":\"javascript:GoToBusiness('D01681188', 0, true);\"}}],\"isFilteredByClient\":false}"
headers = {
  'Content-Type': 'text/plain',
  'Cookie': 'bcookie="v=2&7d264ef9-2352-4e31-88d3-8736cc7c20f3"; lidc="b=VGST06:s=V:r=V:a=V:p=V:g=2954:u=1:x=1:i=1713504058:t=1713590458:v=2:sig=AQERUjtASyu-D2RXK7xSSnQnpz9DDJ2C"; ar_debug=1'
}

response = session.post(url, headers=headers, data=payload)

print(response.text)

# %%
url = "https://egov.maryland.gov/BusinessExpress/EntitySearch/SetBusinessInformationTab"

payload = 'selectedTab=0'
headers = {
  'Accept': '*/*',
  'Accept-Encoding': 'gzip, deflate, br, zstd',
  'Accept-Language': 'en-US,en;q=0.9',
  'Connection': 'keep-alive',
  'Content-Length': '13',
  'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
  'Cookie': '_ga=GA1.1.611269524.1710315831; ASP.NET_SessionId=gpcepz2yy3yu4so4eudibm1m; __RequestVerificationToken_L0J1c2luZXNzRXhwcmVzcw2=3Ppckr1fTr2A1v_48G_rTU1SUfWRug60ogt6nnIKOlq4E6TcrFW2e5rCMAG9GqBe8bz0eiyKLeeOo3WudfW31g8xBGc1; mdegov=!j28GpWUMBqCGe4lMfV4ETUwLkTglz/OIw+ruv57DoKKj3/4TD0vVDTdQULAXGDwh+UOV/9GH+aHM8J3IwYvRvR3fj0qMblyNG1uNitHoums=; _ga_KJKE71WK2Y=GS1.1.1713502684.11.1.1713506550.0.0.0; _ga_LJCC9XG5J9=GS1.1.1713502689.11.1.1713506550.0.0.0',
  'Host': 'egov.maryland.gov',
  'Origin': 'https://egov.maryland.gov',
  'Referer': 'https://egov.maryland.gov/BusinessExpress/EntitySearch/Business',
  'Sec-Ch-Ua': '"Chromium";v="124", "Google Chrome";v="124", "Not-A.Brand";v="99"',
  'Sec-Ch-Ua-Mobile': '?0',
  'Sec-Ch-Ua-Platform': '"Windows"',
  'Sec-Fetch-Dest': 'empty',
  'Sec-Fetch-Mode': 'cors',
  'Sec-Fetch-Site': 'same-origin',
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36',
  'Verificationtoken': 'LDzGoieS4Opu8Wcqx4jnDaoNs07BiAzyomdfHbcIQrIhePSyddn_4vdIu2QMk6rxIvmU8HhhP3JzgObKkhe9-NzdJv41',
  'X-Requested-With': 'XMLHttpRequest'
}

response = session.post(url, headers=headers, data=payload)

print(response.text)

# %%
from twocaptcha import TwoCaptcha
import os
import requests
import json

api_key = os.getenv('APIKEY_2CAPTCHA', 'your_2captcha_key')

solver = TwoCaptcha(api_key)

result = solver.recaptcha(sitekey="6Lc01PUUAAAAAMyGmpXYkDCdKdbPdnOFXpXbP4O8",
                          url='https://egov.maryland.gov/BusinessExpress/EntitySearch/')


print(result)
# Out:
# {'captchaId': '76246635704', 'code': '03AFcWeA7OyhxQz7q0pOd-he4n9Ia9HiaLHl5kDdW5TJkEXzWdkG3D422uPHHDZs8leO6jsnSFt6mk9QXfhH6wdYyqNMkLy74P3SIxRL1PnWrzdrH4GcCxjAS3Hz4qaSxqFNWm4JAJOjZOgnfb1x0etT8qs_-amByOe6IBZobkFHkqjXQagasKBH3NZj406S1o8B-vhAFH_W1gy3s9NppM2HkZEtRGD33k_6vjJOAnp-VfXVWvHXpaCHwDtSPK3QKPXKjn9q6npI78ZCWPgxpmhQGTRzyDIk_TLow5YiV15eDtGAeRc2hqH38jjldLN4H1kZnJpNx-XugYR8TsOtQuvmLVte-JJnj4CKvfrtm92qhvZVXnyh9YaLb5Rk_3yUQSx9rhSwQZ-0J8bvGggxcASVMT9ZqmgPNitFARy3ccSnpR7oFPHFB-Dit4aazdcDmLTUgYlVC_2R56B_H2-2AXSB7VMI-Q2mn30pKEtqKZAb5cYsbKC1Mm8-JNPnbsnH46Gu5YZNd2HKNILu4SmK1pNVt9bw7esLu-cj1gUHk3jCRpQGohFb6oot4bnS6UZUgibPgqMFj89fkM05ONxpa2KBQYry6gzp6jFfTw8EzkiZFzsh-znmcnCR6QqSXejmK6TeLHfoFLJeAL6L7LEsXFUaC-ojIK19bNvvxhZNy1MCQjfteZ2rTTF095x9mp0sfXzYJY_AVIghxTRPWsU0L_CWuKBXJ7_BPMm_zq9I3-8iq7OoKljhNiA3IGR32FgmOCUK85xNjBwTIv1E6WDoNmtqoDrXQCbY-BwvesmJBBqYwzpIWsH506W6fB-a369UjKEQL5asNy3Dle'}

# %%
import requests
from IPython.display import HTML

url = "https://egov.maryland.gov/BusinessExpress/EntitySearch/Business"

gcaptcha = result['code']

payload = f'g-recaptcha-response={gcaptcha}&BusinessDepartmentId=T00516393&TabToShow=0'
headers = {
  'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
  'Accept-Encoding': 'gzip, deflate, br, zstd',
  'Accept-Language': 'en-US,en;q=0.9',
  'Cache-Control': 'max-age=0',
  'Connection': 'keep-alive',
  'Content-Type': 'application/x-www-form-urlencoded',
#   'Cookie': '_ga=GA1.1.611269524.1710315831; ASP.NET_SessionId=gpcepz2yy3yu4so4eudibm1m; __RequestVerificationToken_L0J1c2luZXNzRXhwcmVzcw2=3Ppckr1fTr2A1v_48G_rTU1SUfWRug60ogt6nnIKOlq4E6TcrFW2e5rCMAG9GqBe8bz0eiyKLeeOo3WudfW31g8xBGc1; mdegov=!j28GpWUMBqCGe4lMfV4ETUwLkTglz/OIw+ruv57DoKKj3/4TD0vVDTdQULAXGDwh+UOV/9GH+aHM8J3IwYvRvR3fj0qMblyNG1uNitHoums=; _ga_KJKE71WK2Y=GS1.1.1713502684.11.1.1713507134.0.0.0; _ga_LJCC9XG5J9=GS1.1.1713502689.11.1.1713507134.0.0.0:',
  'Host': 'egov.maryland.gov',
  'Origin': 'https://egov.maryland.gov',
  'Referer': 'https://egov.maryland.gov/businessexpress/EntitySearch/BusinessInformation/T00516393',
  'Sec-Ch-Ua': '"Chromium";v="124", "Google Chrome";v="124", "Not-A.Brand";v="99"',
  'Sec-Ch-Ua-Mobile': '?0',
  'Sec-Ch-Ua-Platform': '"Windows"',
  'Sec-Fetch-Dest': 'document',
  'Sec-Fetch-Mode': 'navigate',
  'Sec-Fetch-Site': 'same-origin',
  'Sec-Fetch-User': '?1',
  'Upgrade-Insecure-Requests': '1',
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36'
}

response = requests.request("POST", url, headers=headers, data=payload)

print(display(HTML(response.text)))
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta http-equiv="X-UA-Compatible" content="IE=Edge" charset="utf-8" />
#     <title>Register Your Business Online | Maryland.gov</title>
#     <meta name="description" content="Easy online tools to register and start a business in Maryland, register a trade name in Maryland and establish tax accounts in Maryland." />
# ...

# %%
response.cookies
# Out:
# <RequestsCookieJar[Cookie(version=0, name='ASP.NET_SessionId', value='qqjshqz1se1kwougc5wo2xlc', port=None, port_specified=False, domain='egov.maryland.gov', domain_specified=False, domain_initial_dot=False, path='/', path_specified=True, secure=True, expires=None, discard=True, comment=None, comment_url=None, rest={'HttpOnly': None, 'SameSite': 'Lax'}, rfc2109=False), Cookie(version=0, name='__RequestVerificationToken_L0J1c2luZXNzRXhwcmVzcw2', value='HeeIP-5cRKUR88X3SdFkSBhQxUO9AWxbI0xIbE0d5s4LWvl5gy4J6FojQ5fuUMSkWe7_MFpqmOA4Jp6Rzf48I9if4V81', port=None, port_specified=False, domain='egov.maryland.gov', domain_specified=False, domain_initial_dot=False, path='/', path_specified=True, secure=True, expires=None, discard=True, comment=None, comment_url=None, rest={'HttpOnly': None}, rfc2109=False), Cookie(version=0, name='mdegov', value='!J3Y2FeFjZn5S+AtMfV4ETUwLkTglzwUUDnXFmqHcM9kKuRW4lB97AXdP/75VDSnzMNHDAA8VIrXkOI19V2AmCnUd/EHwVXhU4a9v1qhLzkU=', port=None, port_specified=False, domain
# ...

# %%
import requests
from IPython.display import HTML

url = "https://egov.maryland.gov/businessexpress/EntitySearch/BusinessInformation/T00516393"

session= requests.Session()
# payload = f'g-recaptcha-response={gcaptcha}&BusinessDepartmentId=W05671227&TabToShow=0'
headers = {
  # 'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
  # 'Accept-Encoding': 'gzip, deflate, br, zstd',
  # 'Accept-Language': 'en-US,en;q=0.9',
  # 'Cache-Control': 'max-age=0',
  # 'Connection': 'keep-alive',
  # 'Content-Type': 'application/x-www-form-urlencoded',
#   'Cookie': '_ga=GA1.1.611269524.1710315831; ASP.NET_SessionId=gpcepz2yy3yu4so4eudibm1m; __RequestVerificationToken_L0J1c2luZXNzRXhwcmVzcw2=3Ppckr1fTr2A1v_48G_rTU1SUfWRug60ogt6nnIKOlq4E6TcrFW2e5rCMAG9GqBe8bz0eiyKLeeOo3WudfW31g8xBGc1; mdegov=!j28GpWUMBqCGe4lMfV4ETUwLkTglz/OIw+ruv57DoKKj3/4TD0vVDTdQULAXGDwh+UOV/9GH+aHM8J3IwYvRvR3fj0qMblyNG1uNitHoums=; _ga_KJKE71WK2Y=GS1.1.1713502684.11.1.1713507134.0.0.0; _ga_LJCC9XG5J9=GS1.1.1713502689.11.1.1713507134.0.0.0:',
  'Cookie': 'ASP.NET_SessionId=qqjshqz1se1kwougc5wo2xlc; __RequestVerificationToken_L0J1c2luZXNzRXhwcmVzcw2=HeeIP-5cRKUR88X3SdFkSBhQxUO9AWxbI0xIbE0d5s4LWvl5gy4J6FojQ5fuUMSkWe7_MFpqmOA4Jp6Rzf48I9if4V81; mdegov=!J3Y2FeFjZn5S+AtMfV4ETUwLkTglzwUUDnXFmqHcM9kKuRW4lB97AXdP/75VDSnzMNHDAA8VIrXkOI19V2AmCnUd/EHwVXhU4a9v1qhLzkU=;',
  # 'Host': 'egov.maryland.gov',
  # 'Origin': 'https://egov.maryland.gov',
  # 'Referer': 'https://egov.maryland.gov/businessexpress/EntitySearch/BusinessInformation/T00516393',
  # 'Sec-Ch-Ua': '"Chromium";v="124", "Google Chrome";v="124", "Not-A.Brand";v="99"',
  # 'Sec-Ch-Ua-Mobile': '?0',
  # 'Sec-Ch-Ua-Platform': '"Windows"',
  # 'Sec-Fetch-Dest': 'document',
  # 'Sec-Fetch-Mode': 'navigate',
  # 'Sec-Fetch-Site': 'same-origin',
  # 'Sec-Fetch-User': '?1',
  # 'Upgrade-Insecure-Requests': '1',
  # 'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36'
}

response = session.get(url, headers=headers, data=payload)

print(display(HTML(response.text)))
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta http-equiv="X-UA-Compatible" content="IE=Edge" charset="utf-8" />
#     <title>Register Your Business Online | Maryland.gov</title>
#     <meta name="description" content="Easy online tools to register and start a business in Maryland, register a trade name in Maryland and establish tax accounts in Maryland." />
# ...

# %%
response.headers
# Out:
# {'Cache-Control': 'private', 'Content-Type': 'text/html; charset=utf-8', 'Server': '', 'X-XSS-Protection': '1; mode=block', 'x-frame-options': 'SAMEORIGIN', 'Mc': '05c', 'Date': 'Fri, 19 Apr 2024 07:39:36 GMT', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'Vary': 'Accept-Encoding', 'Content-Encoding': 'gzip', 'Content-Length': '5590', 'Connection': 'Keep-Alive'}

# %%
from twocaptcha import TwoCaptcha
import os
import requests
import json

api_key = os.getenv('APIKEY_2CAPTCHA', 'your_2captcha_key')

solver = TwoCaptcha(api_key)

result = solver.recaptcha(sitekey="6Lc01PUUAAAAAMyGmpXYkDCdKdbPdnOFXpXbP4O8",
                          url='https://egov.maryland.gov/BusinessExpress/EntitySearch/')


print(result)
# Out:
# {'captchaId': '76224704590', 'code': '03AFcWeA6q1qnuxE4y1a74iQygV2CIbwiMgP6KmbUCepZu9Ws8zRN6tGySSqEaBTe7zqlb10Z6RW0g1ao_Np4E3BwPmdn7M_vvNVhAtztNjTHEEqijWxfM7hSc7znla4f7TBkAz2WgYMT2ULJrq2p0IHg40wPVB73mjWWUascnnLU7coMD6FJNcb1ELcL9Ef-QkRKsRwwaJAdiWZEM8W6AHEn89eQMFBlxjb0KlwqSPLoLmaZ36VWhxns_PrlaxIU_b7HkMMWIUjmPj66LX-DMti7usDgK69ZFAN_qmmxXztia15ZBsq4ZgcYYIURqS3whioNPTQ5vTAonb9gKvtthsqPIOcyP-KuNBrMOrHUTJTu6NPx_rkDWBpXxnV28YObjmXob64PNCOWUS-Ip2La3GkFWLzalMBWEdkd82ONfg5MZn7vymuBxZQIS9S83LcoI1bNld3qMYiz8E_CZLbqgvhm86xAVeQho1qn8cB1rmMFK-G28vLO1X8MLITJuXIcUjwRhP2_EcqHbAWi_T9sy-tfKVqTxUMB-KiQVcGJPVAzDJr9lkT1UyUiBGY8R-UNniISvk_GwK9nTYptkRb6X4BH4Qxwa9YlZYt_lVkd1GF--M2HdTpuaIld3F8bgqHHBCLnCAvzyjyxoxOh8Nt7OC1RhxqRptZouTZUn6MkvCgMoyX3Vt3h0MiM7tObDPe0K8FQjbU4D-szU0nXloZxqnXolL7fQTEdYi3sR6dcfj3mqJ3m4OA207WGYPgtVr-YWhcQKwv0hKE1mgMvWF90nLNvC5ObvpVDA1g'}

# %%
import requests
from IPython.display import HTML


session = requests.Session()
url = "https://egov.maryland.gov/BusinessExpress/EntitySearch"
gcaptcha = result['code']
payload = f'__RequestVerificationToken=1eQLqyccS0CtASGtcZkgBVxIomoqjZkCCeSZKaAfn9Y2DyMqW2kee_r-HsW63yX2AcMpEwlrRHu2iI5viFOyMYEuyFU1&SearchAction=Search&ReturnUrl=&CblpLinkId=0&UserRegistrationId=0&FilingId=0&Subheading=&g-recaptcha-response={gcaptcha}&BusinessName=aa&DepartmentId=&FEINNumber=&SearchType=BusinessName'
headers = {
  'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
  'Accept-Encoding': 'gzip, deflate, br, zstd',
  'Accept-Language': 'en-US,en;q=0.9',
  'Cache-Control': 'max-age=0',
  'Connection': 'keep-alive',
  'Content-Type': 'application/x-www-form-urlencoded',
  'Host': 'egov.maryland.gov',
  'Origin': 'https://egov.maryland.gov',
  'Referer': 'https://egov.maryland.gov/BusinessExpress/EntitySearch',
  'Sec-Ch-Ua': '"Chromium";v="124", "Google Chrome";v="124", "Not-A.Brand";v="99"',
  'Sec-Ch-Ua-Mobile': '?0',
  'Sec-Ch-Ua-Platform': '"Windows"',
  'Sec-Fetch-Dest': 'document',
  'Sec-Fetch-Mode': 'navigate',
  'Sec-Fetch-Site': 'same-origin',
  'Sec-Fetch-User': '?1',
  'Upgrade-Insecure-Requests': '1',
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36'
}

response = session.post(url, headers=headers, data=payload)

print(display(HTML(response.text)))
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta http-equiv="X-UA-Compatible" content="IE=Edge" charset="utf-8" />
#     <title>Register Your Business Online | Maryland.gov</title>
#     <meta name="description" content="Easy online tools to register and start a business in Maryland, register a trade name in Maryland and establish tax accounts in Maryland." />
# ...

# %%
import requests
from IPython.display import HTML

url = "https://egov.maryland.gov/BusinessExpress/EntitySearch/Business"

gcaptcha = result['code']

payload = f'BusinessDepartmentId=T00516393&TabToShow=0'
headers = {
  'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
  'Accept-Encoding': 'gzip, deflate, br, zstd',
  'Accept-Language': 'en-US,en;q=0.9',
  'Cache-Control': 'max-age=0',
  'Connection': 'keep-alive',
  'Content-Type': 'application/x-www-form-urlencoded',
  'Cookie': 'ASP.NET_SessionId=erpe1tsknetlzdhq5b0bxpke; __RequestVerificationToken_L0J1c2luZXNzRXhwcmVzcw2=NW4wGacOt7VN0aM4lWVCl73HH3a-oUyuS6jm0e7OU5uQKAbFRYi6_8t1xWJi4eS2uvKl8d7xuVRuyDiaLh6h023ZcG41; mdegov=!BAvpv4rhFbe3zh9MfV4ETUwLkTglz4ST0+WM0IIIWNA+8230Qy/fTlTxyVhqOi8XZCK5ge/YwUZ4reZFaOWsFJJokjloqMWZQAqj9BKQTNA=;',

#   'Cookie': '_ga=GA1.1.611269524.1710315831; ASP.NET_SessionId=gpcepz2yy3yu4so4eudibm1m; __RequestVerificationToken_L0J1c2luZXNzRXhwcmVzcw2=3Ppckr1fTr2A1v_48G_rTU1SUfWRug60ogt6nnIKOlq4E6TcrFW2e5rCMAG9GqBe8bz0eiyKLeeOo3WudfW31g8xBGc1; mdegov=!j28GpWUMBqCGe4lMfV4ETUwLkTglz/OIw+ruv57DoKKj3/4TD0vVDTdQULAXGDwh+UOV/9GH+aHM8J3IwYvRvR3fj0qMblyNG1uNitHoums=; _ga_KJKE71WK2Y=GS1.1.1713502684.11.1.1713507134.0.0.0; _ga_LJCC9XG5J9=GS1.1.1713502689.11.1.1713507134.0.0.0:',
  'Host': 'egov.maryland.gov',
  'Origin': 'https://egov.maryland.gov',
  'Referer': 'https://egov.maryland.gov/businessexpress/EntitySearch/BusinessInformation/T00516393',
  'Sec-Ch-Ua': '"Chromium";v="124", "Google Chrome";v="124", "Not-A.Brand";v="99"',
  'Sec-Ch-Ua-Mobile': '?0',
  'Sec-Ch-Ua-Platform': '"Windows"',
  'Sec-Fetch-Dest': 'document',
  'Sec-Fetch-Mode': 'navigate',
  'Sec-Fetch-Site': 'same-origin',
  'Sec-Fetch-User': '?1',
  'Upgrade-Insecure-Requests': '1',
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36'
}

response = session.request("POST", url, headers=headers, data=payload)

print(display(HTML(response.text)))
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta http-equiv="X-UA-Compatible" content="IE=Edge" charset="utf-8" />
#     <title>Register Your Business Online | Maryland.gov</title>
#     <meta name="description" content="Easy online tools to register and start a business in Maryland, register a trade name in Maryland and establish tax accounts in Maryland." />
# ...

# %%
response.text
# Out:
# '<!DOCTYPE html>\r\n<html lang="en">\r\n<head>\r\n    <meta http-equiv="X-UA-Compatible" content="IE=Edge" charset="utf-8" />\r\n    <title>Register Your Business Online | Maryland.gov</title>\r\n    <meta name="description" content="Easy online tools to register and start a business in Maryland, register a trade name in Maryland and establish tax accounts in Maryland." />\r\n    <meta name="keywords" content="Business in Maryland, Start a business in Maryland, Register a business in Maryland, Create a business in Maryland, Maryland business resources, Maryland Business Express, Legal business entity, Maryland Department of Assessments and Taxation, Register a business Trade Name, Register a business Trade Name with the Maryland Department of Assessments and Taxation, Establish tax accounts, Establish tax accounts with the Comptroller of Maryland, Sole Proprietorship, General Partnership, Limited Liability Company, Stock Corporation, Tax-Exempt Nonstock Corporation, Close Corporation
# ...

# %%
response.cookies
# Out:
# <RequestsCookieJar[Cookie(version=0, name='ASP.NET_SessionId', value='erpe1tsknetlzdhq5b0bxpke', port=None, port_specified=False, domain='egov.maryland.gov', domain_specified=False, domain_initial_dot=False, path='/', path_specified=True, secure=True, expires=None, discard=True, comment=None, comment_url=None, rest={'HttpOnly': None, 'SameSite': 'Lax'}, rfc2109=False), Cookie(version=0, name='__RequestVerificationToken_L0J1c2luZXNzRXhwcmVzcw2', value='NW4wGacOt7VN0aM4lWVCl73HH3a-oUyuS6jm0e7OU5uQKAbFRYi6_8t1xWJi4eS2uvKl8d7xuVRuyDiaLh6h023ZcG41', port=None, port_specified=False, domain='egov.maryland.gov', domain_specified=False, domain_initial_dot=False, path='/', path_specified=True, secure=True, expires=None, discard=True, comment=None, comment_url=None, rest={'HttpOnly': None}, rfc2109=False), Cookie(version=0, name='mdegov', value='!BAvpv4rhFbe3zh9MfV4ETUwLkTglz4ST0+WM0IIIWNA+8230Qy/fTlTxyVhqOi8XZCK5ge/YwUZ4reZFaOWsFJJokjloqMWZQAqj9BKQTNA=', port=None, port_specified=False, domain
# ...

# %%
import requests
from IPython.display import HTML

url = "https://egov.maryland.gov/BusinessExpress/EntitySearch/SetBusinessInformationTab"

payload = 'selectedTab=0'
headers = {
  # 'Accept': '*/*',
  # 'Accept-Encoding': 'gzip, deflate, br, zstd',
  # 'Accept-Language': 'en-US,en;q=0.9',
  # 'Connection': 'keep-alive',
  # 'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
  'Cookie': 'ASP.NET_SessionId=erpe1tsknetlzdhq5b0bxpke; __RequestVerificationToken_L0J1c2luZXNzRXhwcmVzcw2=NW4wGacOt7VN0aM4lWVCl73HH3a-oUyuS6jm0e7OU5uQKAbFRYi6_8t1xWJi4eS2uvKl8d7xuVRuyDiaLh6h023ZcG41; mdegov=!BAvpv4rhFbe3zh9MfV4ETUwLkTglz4ST0+WM0IIIWNA+8230Qy/fTlTxyVhqOi8XZCK5ge/YwUZ4reZFaOWsFJJokjloqMWZQAqj9BKQTNA=;',
  'Host': 'egov.maryland.gov',
  'Origin': 'https://egov.maryland.gov',
  'Referer': 'https://egov.maryland.gov/BusinessExpress/EntitySearch/Business',
  # 'Sec-Ch-Ua': '"Chromium";v="124", "Google Chrome";v="124", "Not-A.Brand";v="99":',
  # 'Sec-Ch-Ua-Mobile': '?0',
  # 'Sec-Ch-Ua-Platform': '"Windows"',
  # 'Sec-Fetch-Dest': 'empty',
  # 'Sec-Fetch-Mode': 'cors',
  # 'Sec-Fetch-Site': 'same-origin',
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36',
  'Verificationtoken': "zn9r-ZPLG0_3DcBKwJHUnYEqYJXGbAhOomR4OVzc_SNPYNphpwH6ieGeedU78j45XT30MBFiUo7-GG4kSpmZc2gzVh81",
  # 'X-Requested-With': 'XMLHttpRequest'
}

response1 = session.get(url, headers=headers, data=payload)

print(display(HTML(response1.text)))
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta http-equiv="X-UA-Compatible" content="IE=Edge" charset="utf-8" />
#     <title>Register Your Business Online | Maryland.gov</title>
#     <meta name="description" content="Easy online tools to register and start a business in Maryland, register a trade name in Maryland and establish tax accounts in Maryland." />
# ...
